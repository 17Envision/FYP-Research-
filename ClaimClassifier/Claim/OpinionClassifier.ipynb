# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# %%
df = pd.read_csv('../../data/TKCOMMENT_7210499881536916737_3970_comments.csv')

# %%
df.head()
# Out:
#             Comment Id              User Id       Unique Id  \
# 0  7210615196103377671  6943198443339891717   music_cafe_00
# 1  7210440435021300481  6920361002287449089   gaurawanuwan0
# 2  7210593874347131650  6823475459679159302  1_sachi_girl_1
# 3  7210803442351522561  6754500001639187462   jsheehehhdyye
# 4  7210584265703293698  6889016588059722758     dilusha2000
#
#              Nickname                                             Avatar  \
# 0  🎧 | MUSIC CAFE | 🎧  https://p16-sign-useast2a.tiktokcdn.com/tos-us...
# 1       Gaurawa Nuwan  https://p16-sign-useast2a.tiktokcdn.com/tos-us...
# 2         🧚💛_MUTHU_💛🧚  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 3        hshshhshhshs  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
# 4    dilu -boy x.....  https://p16-sign-sg.tiktokcdn.com/aweme/100x10...
#
#                                  User URL  Reply Comment Id  \
# 0   https://www.tiktok.com/@music_cafe_00                 0
# ...

# %%
df.describe()
# Out:
#          Comment Id       User Id  Reply Comment Id   Digg Count  Reply Count  \
# count  3.970000e+03  3.970000e+03      3.970000e+03  3970.000000  3904.000000
# mean   7.221770e+18  6.953478e+18      1.199558e+17     1.136524     0.074283
# std    2.123808e+16  4.107298e+17      9.226974e+17    22.970278     1.103933
# min    7.210438e+18  1.690231e+15      0.000000e+00     0.000000     0.000000
# 25%    7.210718e+18  6.849306e+18      0.000000e+00     0.000000     0.000000
# 50%    7.211414e+18  6.998108e+18      0.000000e+00     0.000000     0.000000
# 75%    7.230551e+18  7.119436e+18      0.000000e+00     0.000000     0.000000
# max    7.331623e+18  7.321315e+18      7.238263e+18  1075.000000    47.000000
#
#            Video Id
# count  3.970000e+03
# mean   7.210500e+18
# std    1.024129e+03
# min    7.210500e+18
# 25%    7.210500e+18
# 50%    7.210500e+18
# 75%    7.210500e+18
# max    7.210500e+18

# %%
df.isnull().sum()
# Out:
# Comment Id            0
# User Id               0
# Unique Id             0
# Nickname              1
# Avatar                0
# User URL              0
# Reply Comment Id      0
# Comment               0
# Digg Count            0
# Reply Count          66
# Is Author Digged      0
# Author Pin           66
# Language            420
# Create Time           0
# Video URL             0
# Video Id              0
# dtype: int64
